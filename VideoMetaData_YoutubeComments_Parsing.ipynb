# %%
#Download the video meta data#

# %%
# !python DownloadVideoMetadata.py c VideoIDs.txt DjokovicVideoMetadata Key.txt
# Out:
# 655 videos in list
# Cur video id:  73eT31C1TUQ
# The url:  https://www.googleapis.com/youtube/v3/videos?part=snippet%2Cstatistics%2CcontentDetails&id=73eT31C1TUQ%2C_LqLCO5WcL4%2CpJfGuVAkVvY%2Cqt83abLTwTg%2CoH9jJ8xXteM%2CHKkuwFWybpY%2C06rXGc0ES58%2CMpANiLpgiYk%2C7582OORlvxU%2CF_sRXrNQRhM%2ChKrRwl0R1Jg%2CbKaDHLiGN6U%2CT8e7kYC8x2M%2CjPcvXB6xrsg%2C/shorts/SaiR1C6eZTA%2C%2C_xe70e2xMds%2CkhUw03SmWEg%2C9U2W5oT2KM4%2CxHmyV7uFWRI%2Cs0IMJgIEaT8%2CSn_0oy4vQWo%2C4dJZuAHriNQ%2Ce8fzcfhxtNI%2CeIAqn2SS6bo%2CfCwfqpymyZk%2CaBe3maAGftQ%2C5AU8FQVJXZ8%2CchdwWDuHC1Q%2Cfu_i4cyowWY%2CDOty8oyGCNU%2Ch1NfoHv9zGY%2CJOq_qMdn4vw%2CUgEpeoEpP8Q%2C/shorts/6CwS7NIz0YI%2C%2CDLjLQnfUkHE%2CjG1MJmPtHu4%2CkqjnNTUquvc%2CYXEoJTailEw%2CiqkoameipZI%2C/shorts/DC4wxktynzk%2C%2C/shorts/SaiR1C6eZTA%2C%2C9fdLHES7_9E%2Cld0YZruda3M%2CIZf2UVxMoXE%2CbzrKSv076bE%2C1p4Njiwx7v8&key=AIzaSyC9qCYZGzOp2zjgfR5BUUFlEv9VSxnRgGQ
# 200
# Video index:  50
# Cur video id:  /shorts/m0BNKkgjdA0
# ...

# %%
#Download the youtube Comments#

# %%
# !python DownloadYouTubeComments.py c VideoIDs.txt DjokovicComments Key.txt
# Out:
# Hello
# 655 videos in list
# Cur video id:  73eT31C1TUQ
# Cur pg:  0
# The url:  https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyC9qCYZGzOp2zjgfR5BUUFlEv9VSxnRgGQ&textFormat=plainText&part=snippet&videoId=73eT31C1TUQ&maxResults=100
# 200
# Video id:  73eT31C1TUQ Page: 0
# Next Page Token : QURTSl9pMXBxMHc5ZGs5S3NuYXZpUnpjRnRwaG9WbkFtM0VyN3pIYi04QUVHNG1RdHZIT3NaN3p5bVdjc1c0Nm91ZEVOT24wOE84MTU5WQ==
# The url:  https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyC9qCYZGzOp2zjgfR5BUUFlEv9VSxnRgGQ&textFormat=plainText&part=snippet&videoId=73eT31C1TUQ&maxResults=100&pageToken=QURTSl9pMXBxMHc5ZGs5S3NuYXZpUnpjRnRwaG9WbkFtM0VyN3pIYi04QUVHNG1RdHZIT3NaN3p5bVdjc1c0Nm91ZEVOT24wOE84MTU5WQ==
# 200
# Video id:  73eT31C1TUQ Page: 1
# Next Page Token : QURTSl9pMFB4TzRacTB2NTV4U2l4NEVqRUczdTJCcDNpeG00X3Bnd2o1VHJySGt1OVp2ckN5MHdZb1ctYm5CM0k1SFEwNDF2U015WFRkZw==
# ...

# %%
#Parse the Comments#

# %%
# !python ParseComments.py DjokovicVideoComments DjokovicVideoCOmmentsParsed
# Out:
# Creating save directory
# Creating save subdirectories
# Found 0 comments from video ID DjokovicVideoCOmmentsParsed
# Writing comment mdetadata to DjokovicVideoCOmmentsParsed\metadata/DjokovicVideoCOmmentsParsed_metadata.csv
# Writing jsonbyline to DjokovicVideoCOmmentsParsed\jsonbyline/DjokovicVideoCOmmentsParsed_jsonbyline.txt
# Found 0 comments from video ID
